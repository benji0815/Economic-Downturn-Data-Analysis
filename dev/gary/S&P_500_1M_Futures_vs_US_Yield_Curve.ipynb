# %%
#Starter File 

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
sp_500_div_yield = "S&P_500_1M_Futures.csv"
us_yield_curve = "US_Yield_Curve.csv"

sp_500_1m_futures = pd.read_csv(sp_500_1m_futures)
us_yield_curve = pd.read_csv(us_yield_curve)

sp_500_1m_futures.head()
# Out:
#         Date    Open    High     Low    Last  Change  Settle  Volume  \
# 0  3/19/2020     NaN     NaN     NaN     NaN    10.7  2403.3    4764
# 1  3/18/2020     NaN     NaN     NaN     NaN    81.5  2414.0    5300
# 2  3/17/2020     NaN     NaN     NaN     NaN    79.3  2495.5   10460
# 3  3/16/2020     NaN     NaN     NaN     NaN   279.7  2416.2   10105
# 4  3/13/2020  2614.0  2703.0  2490.0  2695.0   227.0  2695.9   13217
#
#    Previous Day Open Interest
# 0                      108057
# 1                      108108
# 2                      109967
# 3                      107994
# 4                      107183
